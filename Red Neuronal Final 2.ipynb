# %% [markdown]
# # Red neuronal aplicada al reconocimiento de imagenes

# %% [markdown]
# ## Codigo

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import os
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
val_dir = 'C:/Users/octav/OneDrive/Documentos/Tesis red neuronal/RN1BC/validation'
train_dir = 'C:/Users/octav/OneDrive/Documentos/Tesis red neuronal/RN1BC/training'
test_dir = 'C:/Users/octav/OneDrive/Documentos/Tesis red neuronal/RN1BC/test'


train_dir_b = train_dir + "/benign"
train_dir_m = train_dir + "/malign"

val_dir_b = val_dir + "/benign"
val_dir_m = val_dir + "/malign"

num_b_tr = len(os.listdir(train_dir_b))
num_m_tr = len(os.listdir(train_dir_m))

num_tst= len(os.listdir(test_dir))

# %%
num_b_tr,num_m_tr
# Out:
# (1479, 1479)

# %%
num_b_vl = len(os.listdir(val_dir_b))
num_m_vl = len(os.listdir(val_dir_m))

# %%
num_b_vl,num_m_vl
# Out:
# (493, 493)

# %%
total_train = num_b_tr+num_m_tr
total_val = num_b_vl+num_m_vl
total_train, total_val
# Out:
# (2958, 986)

# %%
num_tst
# Out:
# 986

# %%
data_generator = ImageDataGenerator(rescale=1./250,zoom_range=0.2)

# %%
Model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),

tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),
    
tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
tf.keras.layers.MaxPooling2D(2,2),

tf.keras.layers.Flatten(),
tf.keras.layers.Dense(64,activation='softmax')

])

# %%
batch= 100
img_shape = 150
Model.compile(optimizer = 'adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
EPOCHS = 25
val_data_gen = data_generator.flow_from_directory(batch_size =batch,
                                                            directory=val_dir,
                                                            shuffle = False,
                                                            target_size = (img_shape,img_shape),
                                                            class_mode = 'binary')

train_data_gen = data_generator.flow_from_directory(batch_size=batch,
                                                               directory=train_dir,
                                                               shuffle = True,
                                                               target_size = (img_shape,img_shape),
                                                               class_mode = 'binary')
# Out:
# Found 986 images belonging to 2 classes.
# Found 2958 images belonging to 2 classes.

# %% [markdown]
# ## Pruebas

# %% [markdown]
# ### Prueba 1

# %%
history = Model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(batch))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(batch))))
# Out:
# Epoch 1/25
# 30/30 [==============================] - 89s 3s/step - loss: 0.8833 - accuracy: 0.5223 - val_loss: 0.6389 - val_accuracy: 0.5000
# Epoch 2/25
# 30/30 [==============================] - 85s 3s/step - loss: 0.5903 - accuracy: 0.6886 - val_loss: 0.4693 - val_accuracy: 0.8073
# Epoch 3/25
# 30/30 [==============================] - 89s 3s/step - loss: 0.5271 - accuracy: 0.7383 - val_loss: 0.3920 - val_accuracy: 0.8560
# Epoch 4/25
# 30/30 [==============================] - 89s 3s/step - loss: 0.4904 - accuracy: 0.7691 - val_loss: 0.3914 - val_accuracy: 0.8428
# Epoch 5/25
# 30/30 [==============================] - 86s 3s/step - loss: 0.4679 - accuracy: 0.7904 - val_loss: 0.3432 - val_accuracy: 0.8732
# Epoch 6/25
# 30/30 [==============================] - 85s 3s/step - loss: 0.4607 - accuracy: 0.7955 - val_loss: 0.3773 - val_accuracy: 0.8783
# Epoch 7/25
# 30/30 [==============================] - 85s 3s/step - loss: 0.4462 - accuracy: 0.8039 - val_loss: 0.3312 - val_accuracy: 0.8783
# Epoch 8/25
# 30/30 [==============================] - 85s 3s/step - loss: 0.4389 - accuracy: 0.7965 - val_loss: 0.3411 - val_accuracy: 0.8905
# Epoch 9/25
# 30/30 [==============================] - 90s 3s/step - loss: 0.4091 - accuracy: 0.8245 - val_loss: 0.2977 - val_accuracy: 0.8905
# Epoch 10/25
# 30/30 [==============================] - 89s 3s/step - loss: 0.4091 - accuracy: 0.8195 - val_loss: 0.2782 - val_accuracy: 0.8996
# Epoch 11/25
# 30/30 [==============================] - 88s 3s/step - loss: 0.4018 - accuracy: 0.8266 - val_loss: 0.3626 - val_accuracy: 0.8367
# Epoch 12/25
# 30/30 [==============================] - 94s 3s/step - loss: 0.4241 - accuracy: 0.8144 - val_loss: 0.3574 - val_accuracy: 0.8570
# Epoch 13/25
# 30/30 [==============================] - 88s 3s/step - loss: 0.4210 - accuracy: 0.8114 - val_loss: 0.3220 - val_accuracy: 0.8986
# Epoch 14/25
# 30/30 [==============================] - 89s 3s/step - loss: 0.3867 - accuracy: 0.8310 - val_loss: 0.2932 - val_accuracy: 0.8935
# Epoch 15/25
# 30/30 [==============================] - 88s 3s/step - loss: 0.3887 - accuracy: 0.8323 - val_loss: 0.2821 - val_accuracy: 0.9016
# Epoch 16/25
# 30/30 [==============================] - 91s 3s/step - loss: 0.3784 - accuracy: 0.8377 - val_loss: 0.2762 - val_accuracy: 0.9128
# Epoch 17/25
# 30/30 [==============================] - 92s 3s/step - loss: 0.3771 - accuracy: 0.8337 - val_loss: 0.3426 - val_accuracy: 0.8874
# Epoch 18/25
# 30/30 [==============================] - 93s 3s/step - loss: 0.3790 - accuracy: 0.8316 - val_loss: 0.3268 - val_accuracy: 0.9118
# Epoch 19/25
# 30/30 [==============================] - 97s 3s/step - loss: 0.3786 - accuracy: 0.8323 - val_loss: 0.2750 - val_accuracy: 0.9148
# Epoch 20/25
# 30/30 [==============================] - 93s 3s/step - loss: 0.3982 - accuracy: 0.8239 - val_loss: 0.2595 - val_accuracy: 0.9128
# Epoch 21/25
# 30/30 [==============================] - 90s 3s/step - loss: 0.3670 - accuracy: 0.8408 - val_loss: 0.2333 - val_accuracy: 0.9138
# Epoch 22/25
# 30/30 [==============================] - 94s 3s/step - loss: 0.3590 - accuracy: 0.8411 - val_loss: 0.3135 - val_accuracy: 0.8966
# Epoch 23/25
# 30/30 [==============================] - 90s 3s/step - loss: 0.3750 - accuracy: 0.8303 - val_loss: 0.4023 - val_accuracy: 0.8438
# Epoch 24/25
# 30/30 [==============================] - 93s 3s/step - loss: 0.3743 - accuracy: 0.8323 - val_loss: 0.2450 - val_accuracy: 0.9016
# Epoch 25/25
# 30/30 [==============================] - 92s 3s/step - loss: 0.3573 - accuracy: 0.8408 - val_loss: 0.3074 - val_accuracy: 0.8803

# %% [markdown]
# ### Gráfica y predicción prueba 1

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']

acc_train = history.history['accuracy']
acc_val = history.history['val_accuracy']

dic = {'C.E':loss_train,'C.V':loss_val,
       'P.E':acc_train,'P.V':acc_val}
data = pd.DataFrame(dic)

# %%
epochs_loss = range(1,len(loss_val)+1)
epochs_val = range(1,len(acc_val)+1)

fig = plt.figure(figsize=(10, 10))

a1 = plt.subplot2grid((2,3),(0,0),colspan = 2)
a2 = plt.subplot2grid((2,3),(0,2), rowspan = 3,colspan = 2)
a3 = plt.subplot2grid((2,3),(1,0),rowspan = 1, colspan = 2)


a1.plot(epochs_loss, loss_train, 'r', label='Costo de entrenamiento')
a1.plot(epochs_loss, loss_val, 'b', label='Costo de validación')
a1.set_title('Costo de Validación y Entrenamiento')
a1.set_xlabel('Epoca')
a1.set_ylabel('Costo')
a1.grid()
a1.legend()

a2 = sns.heatmap(data,cmap="YlGnBu",annot=True,linewidths=.5,ax=a2)

a3.plot(epochs_val, acc_train, 'g', label='Precisión de entrenamiento')
a3.plot(epochs_val, acc_val, 'b', label='Presición de validación')
a3.set_title('Presición de Validación y Entrenamiento')
a3.set_xlabel('Epoca')
a3.set_ylabel('Precisión')
a3.grid()
a3.legend()

# %%
def testing_image(image_directory): 
    test_image = image.load_img(image_directory, target_size = (150,150))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    result = Model.predict(x=test_image)
    if result[0][0] == 1:
        prediction = 'Benigno'
    else:
        prediction = 'Maligno'
    return prediction

# %%
print(testing_image(test_dir+"/im (1).png"),testing_image(test_dir+"/im (986).png"))
# Out:
# Benigno Maligno

# %%
print(testing_image(test_dir+"/im (450).png"),testing_image(test_dir+"/im (123).png"))
print(testing_image(test_dir+"/im (47).png"),testing_image(test_dir+"/im (850).png"))
print(testing_image(test_dir+"/im (652).png"),testing_image(test_dir+"/im (75).png"))
print(testing_image(test_dir+"/im (98).png"),testing_image(test_dir+"/im (410).png"))
# Out:
# Maligno Maligno
# Benigno Benigno
# Maligno Benigno
# Maligno Benigno

# %%
fig=plt.figure(figsize=(10, 10))
columns = 2
rows = 5

k = int(input('¿Cuántas imagénes desea analizar? '))
for i in range(1,k+1):
    im_num =input('¿Qué número de imagen desea analizar? ') #Puede escoger desde 1 hasta 986
    image_directory = test_dir+"/im ("+im_num+").png"
    fig.add_subplot(rows, columns, i)
    plt.imshow(Image.open(image_directory))
    plt.ylabel("im ("+im_num+"): "+str(testing_image(image_directory)))
# Out:
# ¿Cuántas imagénes desea analizar? 10
# ¿Qué número de imagen desea analizar? 1
# ¿Qué número de imagen desea analizar? 986
# ¿Qué número de imagen desea analizar? 450
# ¿Qué número de imagen desea analizar? 123
# ¿Qué número de imagen desea analizar? 47
# ¿Qué número de imagen desea analizar? 850
# ¿Qué número de imagen desea analizar? 652
# ¿Qué número de imagen desea analizar? 75
# ¿Qué número de imagen desea analizar? 98
# ¿Qué número de imagen desea analizar? 410
